# %% [markdown]
# <a href="https://colab.research.google.com/github/vipinv69/Visualisation-assignment/blob/main/Bar_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #importing libraries
import plotly.express as px

# %%
data = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/USA_Housing.csv') #reading data
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data = data.drop(['Address','Avg. Area Income'],axis = 1)

# %%
data
# Out:
#       Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                5.682861                   7.009188
# 1                6.002900                   6.730821
# 2                5.865890                   8.512727
# 3                7.188236                   5.586729
# 4                5.040555                   7.839388
# ...                   ...                        ...
# 4995             7.830362                   6.137356
# 4996             6.999135                   6.576763
# 4997             7.250591                   4.805081
# 4998             5.534388                   7.130144
# 4999             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# ...

# %%
data.dtypes
# Out:
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# dtype: object

# %%
data = data.astype(int)

# %%
data['Avg. Area Number of Bedrooms'].unique()
# Out:
# array([4, 3, 5, 2, 6])

# %%
data['Avg. Area Number of Bedrooms'].value_counts()
# Out:
# 3    1508
# 4    1450
# 2     828
# 6     612
# 5     602
# Name: Avg. Area Number of Bedrooms, dtype: int64

# %%
data
# Out:
#       Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                       5                          7
# 1                       6                          6
# 2                       5                          8
# 3                       7                          5
# 4                       5                          7
# ...                   ...                        ...
# 4995                    7                          6
# 4996                    6                          6
# 4997                    7                          4
# 4998                    5                          7
# 4999                    5                          6
#
#       Avg. Area Number of Bedrooms  Area Population    Price
# 0                                4            23086  1059033
# 1                                3            40173  1505890
# 2                                5            36882  1058987
# 3                                3            34310  1260616
# ...

# %%
data['Avg. Area Number of Bedrooms'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of bedrooms people preferred the most", color=['green', 'blue', 'pink','orange','violet'])
# Out:
# <AxesSubplot:title={'center':'Number of bedrooms people preferred the most'}>
